# %%
import pandas as pd
import numpy as np
import datetime as dt
import warnings
warnings.filterwarnings("ignore")

# %%
df = pd.read_csv("Unemployment in India (3).csv")

# %%
df.head(5)
# Out:
#            Region         Date  Frequency   Estimated Unemployment Rate (%)  \
# 0  Andhra Pradesh   31-05-2019    Monthly                              3.65
# 1  Andhra Pradesh   30-06-2019    Monthly                              3.05
# 2  Andhra Pradesh   31-07-2019    Monthly                              3.75
# 3  Andhra Pradesh   31-08-2019    Monthly                              3.32
# 4  Andhra Pradesh   30-09-2019    Monthly                              5.17
#
#     Estimated Employed   Estimated Labour Participation Rate (%)   Area
# 0           11999139.0                                     43.24  Rural
# 1           11755881.0                                     42.05  Rural
# 2           12086707.0                                     43.50  Rural
# 3           12285693.0                                     43.97  Rural
# 4           12256762.0                                     44.68  Rural

# %%
df.tail(10)
# Out:
#     Region  Date  Frequency   Estimated Unemployment Rate (%)  \
# 758    NaN   NaN        NaN                               NaN
# 759    NaN   NaN        NaN                               NaN
# 760    NaN   NaN        NaN                               NaN
# 761    NaN   NaN        NaN                               NaN
# 762    NaN   NaN        NaN                               NaN
# 763    NaN   NaN        NaN                               NaN
# 764    NaN   NaN        NaN                               NaN
# 765    NaN   NaN        NaN                               NaN
# 766    NaN   NaN        NaN                               NaN
# 767    NaN   NaN        NaN                               NaN
#
#       Estimated Employed   Estimated Labour Participation Rate (%) Area
# 758                  NaN                                       NaN  NaN
# 759                  NaN                                       NaN  NaN
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 768 entries, 0 to 767
# Data columns (total 7 columns):
#  #   Column                                    Non-Null Count  Dtype
# ---  ------                                    --------------  -----
#  0   Region                                    740 non-null    object
#  1    Date                                     740 non-null    object
#  2    Frequency                                740 non-null    object
#  3    Estimated Unemployment Rate (%)          740 non-null    float64
#  4    Estimated Employed                       740 non-null    float64
#  5    Estimated Labour Participation Rate (%)  740 non-null    float64
#  6   Area                                      740 non-null    object
# dtypes: float64(3), object(4)
# memory usage: 42.1+ KB

# %%
df.columns
# Out:
# Index(['Region', ' Date', ' Frequency', ' Estimated Unemployment Rate (%)',
#        ' Estimated Employed', ' Estimated Labour Participation Rate (%)',
#        'Area'],
#       dtype='object')

# %%
df.columns = ['States', 'Date', 'Frequency', 'Estimated Unemployment Rate', ' Estimated Employed', 'Estimated Labour Participation Rate', 'Region',]

# %%
df.head()
# Out:
#            States         Date Frequency  Estimated Unemployment Rate  \
# 0  Andhra Pradesh   31-05-2019   Monthly                         3.65
# 1  Andhra Pradesh   30-06-2019   Monthly                         3.05
# 2  Andhra Pradesh   31-07-2019   Monthly                         3.75
# 3  Andhra Pradesh   31-08-2019   Monthly                         3.32
# 4  Andhra Pradesh   30-09-2019   Monthly                         5.17
#
#     Estimated Employed  Estimated Labour Participation Rate Region
# 0           11999139.0                                43.24  Rural
# 1           11755881.0                                42.05  Rural
# 2           12086707.0                                43.50  Rural
# 3           12285693.0                                43.97  Rural
# 4           12256762.0                                44.68  Rural

# %%
df["Date"]
# Out:
# 0       31-05-2019
# 1       30-06-2019
# 2       31-07-2019
# 3       31-08-2019
# 4       30-09-2019
#           ...
# 763            NaN
# 764            NaN
# 765            NaN
# 766            NaN
# 767            NaN
# Name: Date, Length: 768, dtype: object

# %%
columnlist = df.columns.tolist()

# %%
for i in columnlist:
        print("the null values in ",i,"is",df[i].isnull().sum())
# Out:
# the null values in  States is 28
# the null values in  Date is 28
# the null values in  Frequency is 28
# the null values in  Estimated Unemployment Rate is 28
# the null values in   Estimated Employed is 28
# the null values in  Estimated Labour Participation Rate is 28
# the null values in  Region is 28

# %%
df.isnull().sum()
# Out:
# States                                 28
# Date                                   28
# Frequency                              28
# Estimated Unemployment Rate            28
#  Estimated Employed                    28
# Estimated Labour Participation Rate    28
# Region                                 28
# dtype: int64

# %%
print((df.isnull().sum()/len(df))*100)
# Out:
# States                                 3.645833
# Date                                   3.645833
# Frequency                              3.645833
# Estimated Unemployment Rate            3.645833
#  Estimated Employed                    3.645833
# Estimated Labour Participation Rate    3.645833
# Region                                 3.645833
# dtype: float64

# %%
#using new function for clean null values is = df.dropna(), and fill null values is = df.fillna()
df_clean = df.dropna()

# %%
print((df_clean.isnull().sum()/len(df_clean))*100)
# Out:
# States                                 0.0
# Date                                   0.0
# Frequency                              0.0
# Estimated Unemployment Rate            0.0
#  Estimated Employed                    0.0
# Estimated Labour Participation Rate    0.0
# Region                                 0.0
# dtype: float64

# %%
df_clean.info
# Out:
# <bound method DataFrame.info of              States         Date Frequency  Estimated Unemployment Rate  \
# 0    Andhra Pradesh   31-05-2019   Monthly                         3.65
# 1    Andhra Pradesh   30-06-2019   Monthly                         3.05
# 2    Andhra Pradesh   31-07-2019   Monthly                         3.75
# 3    Andhra Pradesh   31-08-2019   Monthly                         3.32
# 4    Andhra Pradesh   30-09-2019   Monthly                         5.17
# ..              ...          ...       ...                          ...
# 749     West Bengal   29-02-2020   Monthly                         7.55
# 750     West Bengal   31-03-2020   Monthly                         6.67
# 751     West Bengal   30-04-2020   Monthly                        15.63
# 752     West Bengal   31-05-2020   Monthly                        15.22
# 753     West Bengal   30-06-2020   Monthly                         9.86
#
#       Estimated Employed  Estimated Labour Participation Rate Region
# ...

# %%
df_clean.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 740 entries, 0 to 753
# Data columns (total 7 columns):
#  #   Column                               Non-Null Count  Dtype
# ---  ------                               --------------  -----
#  0   States                               740 non-null    object
#  1   Date                                 740 non-null    object
#  2   Frequency                            740 non-null    object
#  3   Estimated Unemployment Rate          740 non-null    float64
#  4    Estimated Employed                  740 non-null    float64
#  5   Estimated Labour Participation Rate  740 non-null    float64
#  6   Region                               740 non-null    object
# dtypes: float64(3), object(4)
# memory usage: 46.2+ KB

# %%
df_clean.loc[:,"Date"] = pd.to_datetime(df_clean["Date"], dayfirst=True)

# %%
df_clean.loc[:,"Frequency"] = df_clean["Frequency"].astype("category")

# %%
df_clean.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 740 entries, 0 to 753
# Data columns (total 7 columns):
#  #   Column                               Non-Null Count  Dtype
# ---  ------                               --------------  -----
#  0   States                               740 non-null    object
#  1   Date                                 740 non-null    object
#  2   Frequency                            740 non-null    object
#  3   Estimated Unemployment Rate          740 non-null    float64
#  4    Estimated Employed                  740 non-null    float64
#  5   Estimated Labour Participation Rate  740 non-null    float64
#  6   Region                               740 non-null    object
# dtypes: float64(3), object(4)
# memory usage: 46.2+ KB

# %%
#df_clean["Month"] = df_clean["Date"].dt.month

# %%
#pip install matplotlib

# %%
#pip install seaborn

# %%
import  matplotlib.pyplot as plt
import seaborn as sns

# %%
heat_maps = df_clean[['Estimated Unemployment Rate', ' Estimated Employed', 'Estimated Labour Participation Rate']]
heat_maps = heat_maps.corr()

#plottingthe figure
plt.figure(figsize=(10,6))
sns.set_context('notebook',font_scale=1)
sns.heatmap(heat_maps, annot=True);

# %% [markdown]
# #### insights of this chart
# 1 -  Unemployment and Employment have a weak negative correlation (-0.22) — as unemployment rises, employment slightly falls.
# 2 -  Unemployment and Labour Participation have almost zero correlation (0.0026) — they do not move together.
# 3-   Employment and Labour Participation also show no meaningful correlation (0.011) — changes in one don’t affect the other.
# 4-   Overall, the three variables are mostly independent — no strong linear relationships exist in this dataset.

# %%
plt.figure(figsize=(10,4))
sns.barplot(x='Region' , y = 'Estimated Unemployment Rate' , data = df_clean , palette = 'winter')
plt.title("unemployment Rate by Region")
plt.show()

# %% [markdown]
# #### insights of this chart
#  Urban unemployment rate is higher than rural
#
# From the bar heights, the Urban region has a noticeably higher Estimated Unemployment Rate (around 13–14%) compared to the Rural region (around 10%).
# This indicates unemployment is more severe in urban areas in your dataset.
#
# 2. Error bars show variability or confidence
#
# The vertical black lines (error bars) represent standard deviation or confidence intervals.
# Urban has a slightly larger error bar, meaning unemployment rates vary more among the urban samples compared to rural ones.
#
# 3. Seaborn barplot() is showing the mean by default
#
# seaborn.barplot() automatically computes and displays the mean of the selected variable (Estimated Unemployment Rate) for each category (Region).
# So the bars you see are not raw values, but aggregated averages.
#
# 4. The plot uses a custom aesthetic style
#
# You chose:
#
# figsize=(10, 5) → wide and clean chart
#
# palette='winter' → cool color tones

# %% [markdown]
# ### conclusion
# The chart highlights that unemployment is noticeably higher in urban regions compared to rural areas, with urban data also showing greater variability. Since the bar heights represent mean values calculated by seaborn.barplot(), the visualization clearly indicates that urban unemployment is both higher and less consistent. The chosen chart style further makes these differences easy to observe.

# %%
#!pip install warnings

# %%
import warnings
warnings.filterwarnings("ignore")


plt.figure(figsize=(10,5))
sns.scatterplot(
    x = ' Estimated Employed',
    y = 'Estimated Labour Participation Rate',
    hue = 'Region',
    data = df_clean,
    s = 80
)


plt.title("Unemployment vs Labour Participation Rate")
plt.show()

# %% [markdown]
# ### insights of this chart
# 1. The code visualizes the relationship between Employment and Labour Participation
#
# The scatterplot maps:
#
# X-axis: Estimated Employment
#
# Y-axis: Estimated Labour Participation Rate
# This helps identify whether higher employment correlates with higher or lower participation rates.
#
# 2. Data is split by region (Rural vs Urban)
#
# Using
#
# hue='Region'
#
#
# the plot separates Rural (blue) and Urban (orange) observations.
# This allows easy comparison of how these two regions differ in employment and participation behavior.
#
# 3. Urban and Rural clusters show different patterns
#
# From the chart:
#
# Urban points (orange) cluster more towards lower labour participation rates and lower employment values.
#
# Rural points (blue) are more spread out and include higher participation rates.
#
# This suggests Rural areas may have higher participation but more variation.
#
# 4. Marker size is fixed and warnings are suppressed
#
# s = 80 gives all scatter points a uniform medium-large size, improving visibility.
#
# warnings.filterwarnings("ignore") hides non-critical warnings so the notebook output stays clean.

# %% [markdown]
# ### conclusion
# The scatterplot reveals a clear relationship between Estimated Employment and Labour Participation, with noticeable differences between Rural and Urban regions. Rural data points tend to show higher and more varied participation rates, while Urban points cluster around lower participation and employment levels. By separating regions through color coding, the chart makes these contrasting patterns easy to interpret. Overall, the visualization effectively highlights how regional factors influence both employment levels and labour force participation

# %%
state_data = df_clean.groupby('Region')['Estimated Unemployment Rate'].mean().sort_values()

# %%
print(state_data)
# Out:
# Region
# Rural    10.324791
# Urban    13.166614
# Name: Estimated Unemployment Rate, dtype: float64

# %%
plt.figure(figsize=(10 , 6))
plt.pie(
    state_data,
    labels = state_data.index,
    autopct = '%1.1f%%',
    startangle = 90,
)

plt.show()

# %% [markdown]
# ### insights of this chart
# 1. Urban population is the majority
#
# Urban areas account for 56% of the total distribution.
#
# This means more than half of the population represented in the data lives in urban regions.
#
# 2. Rural population is significantly smaller
#
# Rural areas make up 44%, which is 12 percentage points lower than the urban population.
#
# This indicates a noticeable imbalance between rural and urban populations.
#
# 3. Urban dominance may imply higher migration to cities
#
# The larger urban share could be a result of:
#
# Better job opportunities
#
# Education facilities
#
# Healthcare access
#
# This suggests possible urbanization trends.
#
# 4. Resource planning should prioritize both but slightly more toward urban
#
# Since the difference is not extremely large (56% vs 44%), both sectors need focus.
#
# However, urban infrastructure may require more attention due to the majority proportion.

# %% [markdown]
# ### conclusion
# The chart shows that a larger share of the population lives in urban areas (56%) compared to rural regions (44%), indicating a clear but not extreme imbalance. This difference suggests ongoing urbanization, likely driven by better employment, education, and healthcare opportunities in cities. While both regions remain important for planning, the urban majority implies that slightly greater focus may be needed on strengthening urban infrastructure and services to meet the higher population demand.

# %%
plt.figure(figsize=(10 , 5))
sns.lineplot(x = 'Date' ,
             y = 'Estimated Labour Participation Rate',
             hue = 'Region',
             data = df_clean)
plt.show()

# %% [markdown]
# ### insights of this code
# 1. Rural labour participation is consistently higher than urban
#
# Throughout the timeline (2019–2020), the rural region maintains a higher labour participation rate compared to the urban region, showing a consistent gap of around 3–5 percentage points.
#
# 2. Both rural and urban rates show seasonal mild fluctuations before 2020
#
# Before the sharp dip in 2020, both regions show small up-and-down movements, indicating normal seasonal or monthly variations in labour participation. Rural shows slightly more fluctuation than urban.
#
# 3. A major drop occurs around April–May 2020
#
# There is a huge fall in labour participation for both rural and urban areas, with urban dropping even more sharply.
# This aligns with the timing of the COVID-19 lockdown, which severely affected employment across both regions.
#
# 4. Recovery begins after the lockdown period
#
# After the dip in mid-2020, both rural and urban participation rates start rising again, with rural recovering faster and reaching closer to pre-lockdown levels, while urban recovers more slowly.

# %% [markdown]
# ### conclusion
# The labour participation trends show that rural areas consistently maintain higher participation rates than urban regions throughout 2019–2020. Both regions exhibit minor seasonal fluctuations early on, but a sharp and sudden decline appears around April–May 2020 due to the nationwide COVID-19 lockdown. After this disruption, participation rates begin to recover, with rural areas rebounding more quickly and returning closer to pre-lockdown levels, while urban areas recover at a slower pace. Overall, the chart highlights clear regional differences as well as the strong impact of the pandemic on labour activity.

# %%
plt.figure(figsize=(12,5))
plt.plot(df_clean['Date'], df_clean[' Estimated Employed'])
plt.title("Employment Trend Over Time")
plt.xlabel("Date")
plt.ylabel(" Estimated Employed")
plt.grid(True)
plt.show()

# %% [markdown]
# ### insights of this chart
#  1. Employment levels are mostly stable over time
#
# Most lines show small fluctuations but no major upward or downward trend, meaning employment stayed relatively consistent across the period shown.
#
#  2. A few categories have very high employment
#
# Only a small number of lines reach around 4 million, indicating that a few industries/categories contribute a large share of total employment.
#
#  3. Most categories have low employment
#
# The majority of lines remain below 1 million, meaning most industries/categories are smaller and have limited workforce numbers.
#
#  4. Slight dip around early 2020
#
# Many lines show a small decline around March–April 2020, likely due to the early impact of COVID-19 lockdowns.

# %% [markdown]
# ### conclusion
# The chart shows that employment levels across different categories remained mostly stable over time, with only minor fluctuations and no strong long-term trends. A few categories stand out with very high employment—reaching up to around 4 million—while most others remain comparatively small, staying below 1 million. This indicates that only a handful of sectors account for a large share of total employment. There is also a slight dip around early 2020, likely reflecting the initial impact of the COVID-19 lockdown. Overall, the chart highlights stability in employment along with clear differences in the scale of various sectors.

# %%
plt.figure(figsize=(10 , 5))
sns.lineplot(x = 'Date' ,
             y = 'Estimated Unemployment Rate',
             hue = 'Region',
             data = df_clean)
plt.show()

# %% [markdown]
# ### insights of this chart
# Sharp spike in unemployment around mid-2020
# Both rural and urban regions show a massive increase in unemployment rates around May 2020, likely due to the COVID-19 lockdown impact. Urban unemployment rises more sharply than rural.
#
# Urban unemployment is consistently higher
# Throughout the entire timeline, the urban unemployment rate stays above the rural rate, indicating more volatility and sensitivity in urban job markets.
#
# Pre-2020 unemployment is relatively stable
# From mid-2019 to early-2020, both regions show stable and moderate unemployment, with minor fluctuations. There are no major jumps before the pandemic period.
#
# Post-peak decline but still higher than before
# After the sharp rise in mid-2020, both rates start to fall but remain higher than pre-pandemic levels, showing partial recovery but not full normalization.
#
# If you want, I can also summarize this in a short paragraph or extract insights numerically!
# plt.figure(figsize=(12,5)) plt.plot(df_clean['Date'], df_clean['Estimated Employment']) plt.title("Employment Trend Over Time") plt.xlabel("Date") plt.ylabel("Estimated Employment") plt.grid(True) plt.show()

# %% [markdown]
# ### conclusion
# The chart shows that unemployment in both rural and urban regions remained fairly stable before 2020, with only minor fluctuations. However, around May 2020, there is a sharp and sudden spike, most likely caused by the COVID-19 lockdown, with urban unemployment rising even more dramatically than rural. Although unemployment begins to decline after this peak, the levels do not return to their earlier values, indicating that the recovery was only partial. Overall, the data highlights the stronger vulnerability of urban labour markets and the lasting impact of the pandemic on employment conditions

# %%
plt.figure(figsize=(10,5))
plt.scatter(df_clean['Estimated Labour Participation Rate'],
            df_clean['Estimated Unemployment Rate'])

plt.title("Labour Participation vs Unemployment")
plt.xlabel("Labour Participation Rate (%)")
plt.ylabel("Unemployment Rate (%)")
plt.grid(True)
plt.show()

# %% [markdown]
#  ### insights of this chart
#
# 1. No strong linear relationship
#
# The points are widely scattered with no clear upward or downward trend.
#  This means labour participation rate does not have a strong direct connection to unemployment rate.
#
# 2. High unemployment occurs even at mid participation levels
#
# Many points between 40%–60% participation still show unemployment rates as high as 50–80%, indicating that higher participation does not guarantee lower unemployment.
#
# 3. Most data is clustered at lower unemployment
#
# A dense cluster of points is seen around:
#
# Labour Participation: 40%–60%
#
# Unemployment Rate: 0%–20%
# This means most regions have moderate participation and relatively low unemployment.
#
# 4. Outliers with extremely high unemployment
#
# There are some clear outlier points where unemployment shoots above 60–80%, regardless of participation rate.
#  These indicate specific regions or periods with extreme unemployment conditions.

# %% [markdown]
# ### conclusion
# The chart shows that there is no clear linear relationship between labour participation and unemployment, as the points are widely scattered across the plot. Most regions fall within moderate participation levels (40–60%) and relatively low unemployment (0–20%), but several outliers display extremely high unemployment despite varying participation rates. This pattern suggests that higher participation does not necessarily reduce unemployment, and that unemployment levels are influenced by other economic or regional factors beyond participation alone.

# %%
states = df_clean['States'].unique()[:5]  # limit to 5 states for visibility

plt.figure(figsize=(12,6))
for s in states:
    data = df_clean[df_clean['States'] == s]
    plt.plot(data['Date'], data['Estimated Unemployment Rate'], label=s)

plt.title("Unemployment Trend for First 5 States")
plt.xlabel("Date")
plt.ylabel("Estimated Unemployment Rate")
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# ### insight of this chart
#
# 1. Bihar shows the highest unemployment spike
# Among the five states, Bihar has a sharp peak around 50–60%, which is significantly higher than the others.
#  This indicates a period of severe unemployment volatility in Bihar.
#
# 2. Delhi also shows noticeable fluctuations
# Delhi’s line shows a mid-level spike around 40–45%.
#  This suggests Delhi experienced temporary unemployment surges, though not as extreme as Bihar.
#
# 3. Andhra Pradesh and Assam remain relatively stable
# These two states show lower and smoother unemployment trends, without extreme peaks.
#  Their unemployment rates appear more controlled and predictable.
#
# 4. Chhattisgarh shows a rising trend
# Chhattisgarh’s line gradually increases over time, indicating a steady upward trend rather than sudden spikes.
#  This might point to long-term unemployment challenges developing in the state.

# %% [markdown]
# ### conclusion
# The chart highlights clear differences in unemployment trends across the five states. Bihar stands out with the most severe spike, reaching extremely high unemployment levels, indicating a period of major economic disruption. Delhi also experiences noticeable fluctuations, though less extreme than Bihar, suggesting short-term instability. In contrast, Andhra Pradesh and Assam show relatively stable and lower unemployment patterns, reflecting more steady labour market conditions. Chhattisgarh, however, displays a gradual upward trend, pointing to a slowly developing unemployment challenge over time. Overall, the chart shows a mix of volatility, stability, and emerging long-term concerns across different states.

# %% [markdown]
# #### conclusion of overall project
# This project analyzes unemployment, employment, and labor participation trends across Indian states over multiple months. After reviewing the data, the following key conclusions can be drawn:
#
# 1. Significant Variation in Unemployment Across States
#
# Unemployment rates vary widely among states — from very low (around 3–5%) in states like Andhra Pradesh during some months to extremely high values (up to 76%) in certain regions. This indicates clear economic and labor market inequality across India.
#
# 2. Labour Participation Rate Shows Moderate Stability
#
# The Labour Participation Rate (LPR) mostly ranges between 38% and 46%, with an overall average of 42.6%. This suggests that while unemployment fluctuates, the proportion of people participating in the labour market remains relatively stable.
#
# 3. Employment Count Follows Population & Economic Size
#
# States with larger populations or stronger economic activity show higher employment counts (going up to 4.5 crore). Smaller or less industrialized states show much lower employment figures.
#
# 4. Urban vs Rural Differences Are Noticeable
#
# The ‘Area’ column indicates a nearly even distribution of data points between Urban and Rural regions.
# Urban areas often show:
#
# higher unemployment volatility
#
# higher participation rates
# Rural areas usually show more stability but lower employment numbers individually.
#
# 5. Monthly Trends Indicate Economic Sensitivity
#
# Because the dataset uses monthly frequency, it reflects short-term changes in economic conditions. Certain months show spikes in unemployment, possibly due to:
#
# seasonal workforce patterns
#
# industry cycles
#
# economic disruptions
